# %% [markdown]
# <a href="https://colab.research.google.com/github/mohdomer/CodersCave-Internship/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("dataset.csv",encoding='latin-1')

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.tail()
# Out:
#            eventid  iyear  imonth  iday approxdate  extended resolution  \
# 2904  197503270005   1975       3    27        NaN         0        NaN
# 2905  197503270006   1975       3    27        NaN         0        NaN
# 2906  197503270007   1975       3    27        NaN         0        NaN
# 2907  197503270008   1975       3    27        NaN         0        NaN
# 2908  197503270009   1975       3    27        NaN         0        NaN
#
#       country    country_txt  region  ... addnotes scite1 scite2  scite3  \
# 2904      185          Spain       8  ...      NaN    NaN    NaN     NaN
# 2905      185          Spain       8  ...      NaN    NaN    NaN     NaN
# 2906      217  United States       1  ...      NaN    NaN    NaN     NaN
# 2907      217  United States       1  ...      NaN    NaN    NaN     NaN
# 2908      217  United States       1  ...      NaN    NaN    NaN     NaN
#
#       dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2909 entries, 0 to 2908
# Columns: 135 entries, eventid to related
# dtypes: float64(62), int64(22), object(51)
# memory usage: 3.0+ MB

# %%
df.describe()
# Out:
#             eventid        iyear       imonth         iday     extended  \
# count  2.909000e+03  2909.000000  2909.000000  2909.000000  2909.000000
# mean   1.972186e+11  1972.122723     6.138536    15.382606     0.032314
# std    1.584058e+08     1.585828     3.421309     9.095383     0.176862
# min    1.970000e+11  1970.000000     0.000000     0.000000     0.000000
# 25%    1.971022e+11  1971.000000     3.000000     7.000000     0.000000
# 50%    1.972083e+11  1972.000000     6.000000    16.000000     0.000000
# 75%    1.974011e+11  1974.000000     9.000000    23.000000     0.000000
# max    1.975033e+11  1975.000000    12.000000    31.000000     1.000000
#
#            country       region     latitude    longitude  specificity  ...  \
# count  2909.000000  2909.000000  2861.000000  2861.000000  2909.000000  ...
# mean    294.377106     5.131317    35.713904   -35.403239     1.088003  ...
# std     208.206269     3.510636    24.617529    53.617887     0.563527  ...
# ...

# %%
date_cols = ['approxdate', 'resolution']
for col in date_cols:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# %%
missing_values=df.isnull().sum()

# %%
# Distribution of Terrorist Attacks across Regions and Countries
plt.figure(figsize=(12, 6))
sns.countplot(x='region_txt', data=df, order=df['region_txt'].value_counts().index)
plt.title('Distribution of Terrorist Attacks across Regions')
plt.xlabel('Region')
plt.ylabel('No of Attacks')
plt.xticks(rotation=50)
plt.show()

# %%
plt.figure(figsize=(12, 6))
top_countries = df['country_txt'].value_counts().nlargest(15)
sns.barplot(x=top_countries.index, y=top_countries.values)
plt.title('Top 10 Most Targeted Countries')
plt.xlabel('Country')
plt.ylabel('Number of Attacks')
plt.xticks(rotation=50)
plt.show()

# %%
# Trend of Terrorist Attacks Over the Years
plt.figure(figsize=(10, 5))
df['year'] = df['iyear'] + df['imonth'] / 12
sns.lineplot(x='year', y='iyear', data=df)
plt.title('Trend of Terrorist Attacks Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.show()

# %%
# Most Common Attack Types
plt.figure(figsize=(12, 6))
sns.countplot(x='attacktype1_txt', data=df, order=df['attacktype1_txt'].value_counts().index)
plt.title('Most Common Attack Types')
plt.xlabel('Attack Type')
plt.ylabel('Count')
plt.xticks(rotation=50)
plt.show()

# %%
# Casualties and Injuries Analysis
plt.figure(figsize=(12, 6))
sns.scatterplot(x='nkill', y='nwound', data=df, hue='attacktype1_txt', palette='viridis', size='nkill')
plt.title('Casualties and Injuries Analysis')
plt.xlabel('No of Killed')
plt.ylabel('No of Wounded')
plt.legend(title='Attack Type', bbox_to_anchor=(1,1))
plt.show()

# %%
# Analysis of Specific Terrorist Groups
plt.figure(figsize=(12, 6))
top_terrorist_groups = df['gname'].value_counts().nlargest(10)
sns.barplot(x=top_terrorist_groups.index, y=top_terrorist_groups.values, palette='Set3')
plt.title('Top 10 Most Active Terrorist Groups')
plt.xlabel('Terrorist Groups')
plt.ylabel('No of Attacks')
plt.xticks(rotation=50)
plt.show()

# %%
# Correlation Analysis
correlation_matrix = df.corr()

# Display Correlation Matrix as a Table
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#            eventid     iyear    imonth      iday  extended   country  \
# eventid   1.000000  0.999766 -0.041334 -0.004233 -0.001713  0.117312
# iyear     0.999766  1.000000 -0.062903 -0.006332 -0.001883  0.115208
# imonth   -0.041334 -0.062903  1.000000  0.070656  0.007375  0.088699
# iday     -0.004233 -0.006332  0.070656  1.000000  0.012406  0.050678
# extended -0.001713 -0.001883  0.007375  0.012406  1.000000 -0.166557
# ...            ...       ...       ...       ...       ...       ...
# INT_LOG   0.254893  0.251870  0.125614  0.064389  0.073713  0.197770
# INT_IDEO  0.246720  0.243713  0.125340  0.062931  0.090575  0.166570
# INT_MISC  0.245636  0.242621  0.125750  0.037910  0.046757  0.349166
# INT_ANY   0.387993  0.383910  0.168829  0.058803  0.076537  0.283985
# year      0.987554  0.983928  0.116320  0.006340 -0.000555  0.130523
#
#             region  latitude  longitude  specificity  ...  ransomamtus  \
# ...

# %%
# Statistical Analysis
# Example: Hypothesis Testing
from scipy.stats import ttest_ind
# Hypothesis: Is there a significant difference in the number of killed between successful and unsuccessful attacks?
successful_attacks = df[df['success'] == 1]['nkill']
unsuccessful_attacks = df[df['success'] == 0]['nkill']
t_statistic, p_value = ttest_ind(successful_attacks.dropna(), unsuccessful_attacks.dropna(), equal_var=False)
print(f"T-Statistic: {t_statistic}, p-value: {p_value}")
# Out:
# T-Statistic: 8.1201249267391, p-value: 7.219670433629226e-16
